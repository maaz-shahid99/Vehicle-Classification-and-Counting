# %%
import tensorflow as tf

# %%
print(tf.__version__)
# Out:
# 2.10.1

# %%
pwd
# Out:
# 'C:\\Users\\Maaz Shahid\\Desktop\\TF2'

# %%
cd models/research
# Out:
# C:\Users\Maaz Shahid\Desktop\TF2\models\research

# %%
# !protoc object_detection/protos/*.proto --python_out=.

# %%
#!git clone https://github.com/cocodataset/cocoapi.git
# Out:
# Cloning into 'cocoapi'...

# %%
#cd cocoapi/PythonAPI
# Out:
# [WinError 3] The system cannot find the path specified: 'cocoapi/PythonAPI'
# C:\Users\Maaz Shahid\Desktop\TF2\models\research\cocoapi\PythonAPI

# %%
#!MinGW32-make
# Out:
# python setup.py build_ext --inplace
# running build_ext
# skipping 'pycocotools\_mask.c' Cython extension (up-to-date)
# rm -rf build
# process_begin: CreateProcess(NULL, rm -rf build, ...) failed.
# make (e=2): The system cannot find the file specified.
#
# mingw32-make: *** [makefile:4: all] Error 2

# %%
pwd
# Out:
# 'C:\\Users\\Maaz Shahid\\Desktop\\TF2\\models\\research\\cocoapi\\PythonAPI'

# %%
cd research/
# Out:
# C:\Users\Maaz Shahid\Desktop\TF2\models\research

# %%
# !python object_detection/builders/model_builder_tf2_test.py
# Out:
# 2023-01-11 00:53:01.431993: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2023-01-11 00:53:01.432025: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-01-11 00:53:05.376110: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2023-01-11 00:53:05.376683: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-01-11 00:53:05.379354: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: DESKTOP-I88Q7L5
# 2023-01-11 00:53:05.379412: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: DESKTOP-I88Q7L5
# Running tests under Python 3.9.15: C:\Users\Maaz Shahid\.conda\envs\tensorflow\python.exe
# ...

# %%
cd pretrained-models/
# Out:
# C:\Users\Maaz Shahid\Desktop\TF2\pretrained-models

# %%
# !wget http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz
# Out:
# --2023-01-11 01:19:08--  http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 142.250.76.80
# Connecting to download.tensorflow.org (download.tensorflow.org)|142.250.76.80|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20515344 (20M) [application/x-tar]
# Saving to: 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz'
#
#      0K .......... .......... .......... .......... ..........  0%  537K 37s
#     50K .......... .......... .......... .......... ..........  0% 1.10M 27s
#    100K .......... .......... .......... .......... ..........  0% 1.88M 22s
#    150K .......... .......... .......... .......... ..........  0% 2.45M 18s
#    200K .......... .......... .......... .......... ..........  1% 3.43M 16s
#    250K .......... .......... .......... .......... ..........  1% 2.71M 14s
# ...

# %%
# !tar -xvf ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz
# Out:
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/checkpoint
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.index
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/saved_model.pb
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.data-00000-of-00001
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.index

# %%
#cd tensorflow
# Out:
# C:\Users\Maaz Shahid\Desktop\TF2\tensorflow

# %%
# Create train data:
# !python generate_tfrecord.py -x C:/Users/"Maaz Shahid"/Desktop/TF2/tensorflow/train -l C:/Users/"Maaz Shahid"/Desktop/TF2/tensorflow/annotations/label_map.pbtxt -o C:/Users/"Maaz Shahid"/Desktop/TF2/tensorflow/annotations/train.record

# Create test data:
# !python generate_tfrecord.py -x C:/Users/"Maaz Shahid"/Desktop/TF2/tensorflow/test -l C:/Users/"Maaz Shahid"/Desktop/TF2/tensorflow/annotations/label_map.pbtxt -o C:/Users/"Maaz Shahid"/Desktop/TF2/tensorflow/annotations/test.record
# Out:
# Successfully created the TFRecord file: C:/Users/Maaz Shahid/Desktop/TF2/tensorflow/annotations/train.record
# Successfully created the TFRecord file: C:/Users/Maaz Shahid/Desktop/TF2/tensorflow/annotations/test.record

# %%
cd model
# Out:
# C:\Users\Maaz Shahid\Desktop\TF2\tensorflow\model

# %%
mkdir my_ssdnet

# %%
cd ../
# Out:
# C:\Users\Maaz Shahid\Desktop\TF2\tensorflow

# %%
print(tf.compat.v1.gfile.FastGFile('C:/Users/Maaz Shahid/Desktop/TF2/tensorflow/model/my_ssdnet', mode='r'))

# %%
# !python model_main_tf2.py --model_dir=tf.compat.v1.gfile.FastGFile('C:/Users/Maaz Shahid/Desktop/TF2/tensorflow/model/my_ssdnet', mode='r') --pipeline_config_path=C:/Users/"Maaz Shahid"/Desktop/TF2/tensorflow/model/my_ssdnet/pipeline.config
# Out:
# 2023-01-11 02:43:53.955060: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2023-01-11 02:43:53.955093: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-01-11 02:43:57.225558: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2023-01-11 02:43:57.225584: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-01-11 02:43:57.227747: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: DESKTOP-I88Q7L5
# 2023-01-11 02:43:57.227802: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: DESKTOP-I88Q7L5
# ...
